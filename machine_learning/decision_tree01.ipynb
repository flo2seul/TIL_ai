# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree
from IPython.display import display
golf_data = pd.read_csv('../datasets/decision/playing_golf.csv')
display(golf_data.head())
#원핫 인코딩
golf_encoded = pd.get_dummies(golf_data, drop_first=True)
display(golf_encoded.head())
x_golf = golf_encoded.drop(columns=['play_yes'])
y_golf = golf_encoded['play_yes']

model = DecisionTreeClassifier(random_state=42)
model.fit(x_golf, y_golf)
plt.figure(figsize=(15, 8))
#트리 그리기
plot_tree(model, feature_names=x_golf.columns, class_names=['No', 'Yes'], filled=True, rounded=True)
plt.show()
# Out:
#     outlook temperature humidity  windy play
# 0     sunny         hot     high  False   no
# 1     sunny         hot     high   True   no
# 2  overcast         hot     high  False  yes
# 3     rainy        mild     high  False  yes
# 4     rainy        cool   normal  False  yes
#    windy  outlook_rainy  outlook_sunny  temperature_hot  temperature_mild  \
# 0  False          False           True             True             False
# 1   True          False           True             True             False
# 2  False          False          False             True             False
# 3  False           True          False            False              True
# 4  False           True          False            False             False
#
#    humidity_normal  play_yes
# 0            False     False
# 1            False     False
# 2            False      True
# 3            False      True
# 4             True      True
